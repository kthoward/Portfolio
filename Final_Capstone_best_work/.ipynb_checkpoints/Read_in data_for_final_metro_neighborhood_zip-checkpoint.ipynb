# %%
import pandas as pd
from datetime import datetime
import json
import glob
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Key for datasets and columns

# %%
list_of_file_names = glob.glob("./Zip_2/*.csv")
#new_list = []
#for file_name in list_of_file_names:
 #   new = file_name.encode('utf-8').strip()
  #  new_list.append(new)

# %%
read_data_list_2 = []
fail_list = []
for i, data in enumerate(list_of_file_names):
    try:
        data = pd.read_csv(data)
        #data = unicode(data, errors='replace')
        read_data_list_2.append(data)
    except UnicodeDecodeError:
        fail_list.append(i)
#read_data_list
fail_list
list_of_file_names_org = list_of_file_names

# %%
fail_list
# Out:
# [3]

# %%
for x in fail_list:
    del list_of_file_names[x]

# %%
len(list_of_file_names)
# Out:
# 83

# %%
len(read_data_list_2)
# Out:
# 83

# %%
print(df_zillow['file_names'][3])
# Out:
# ./Zip_2/Zip_Listings_PriceCut_SeasAdj_AllHomes.csv

# %%
df_zillow = pd.DataFrame()
df_zillow['file_names'] = list_of_file_names
df_zillow.head(50)
# Out:
#                                            file_names
# 0                    ./Zip_2/BuyerSellerIndex_Zip.csv
# 1         ./Zip_2/InventoryMeasure_SSA_Zip_Public.csv
# 2             ./Zip_2/InventoryMeasure_Zip_Public.csv
# 3   ./Zip_2/Zip_Listings_PriceCut_SeasAdj_AllHomes...
# 4   ./Zip_2/Zip_Listings_PriceCut_SeasAdj_Condomin...
# 5   ./Zip_2/Zip_Listings_PriceCut_SeasAdj_SingleFa...
# 6     ./Zip_2/Zip_Median_PriceCut_Dollar_AllHomes.csv
# 7   ./Zip_2/Zip_Median_PriceCut_Dollar_Condominum.csv
# 8   ./Zip_2/Zip_Median_PriceCut_Dollar_SingleFamil...
# 9         ./Zip_2/Zip_MedianListingPrice_1Bedroom.csv
# 10        ./Zip_2/Zip_MedianListingPrice_2Bedroom.csv
# 11        ./Zip_2/Zip_MedianListingPrice_3Bedroom.csv
# 12        ./Zip_2/Zip_MedianListingPrice_4Bedroom.csv
# 13  ./Zip_2/Zip_MedianListingPrice_5BedroomOrMore.csv
# 14        ./Zip_2/Zip_MedianListingPrice_AllHomes.csv
# 15       ./Zip_2/Zip_MedianListingPrice_CondoCoop.csv
# 16   ./Zip_2/Zip_MedianListingPrice_DuplexTriplex.csv
# 17             ./Zip_2/Zip_MedianListingPrice_Sfr.csv
# 18  ./Zip_2/Zip_MedianListingPricePerSqft_1Bedroom...
# 19  ./Zip_2/Zip_MedianListingPricePerSqft_2Bedroom...
# 20  ./Zip_2/Zip_MedianListingPricePerSqft_3Bedroom...
# 21  ./Zip_2/Zip_MedianListingPricePerSqft_4Bedroom...
# 22  ./Zip_2/Zip_MedianListingPricePerSqft_5Bedroom...
# 23  ./Zip_2/Zip_MedianListingPricePerSqft_AllHomes...
# 24  ./Zip_2/Zip_MedianListingPricePerSqft_CondoCoo...
# 25  ./Zip_2/Zip_MedianListingPricePerSqft_DuplexTr...
# 26      ./Zip_2/Zip_MedianListingPricePerSqft_Sfr.csv
# 27  ./Zip_2/Zip_MedianPctOfPriceReduction_AllHomes...
# 28  ./Zip_2/Zip_MedianPctOfPriceReduction_Condomin...
# 29  ./Zip_2/Zip_MedianPctOfPriceReduction_SingleFa...
# 30         ./Zip_2/Zip_MedianRentalPrice_1Bedroom.csv
# 31         ./Zip_2/Zip_MedianRentalPrice_2Bedroom.csv
# 32         ./Zip_2/Zip_MedianRentalPrice_3Bedroom.csv
# 33         ./Zip_2/Zip_MedianRentalPrice_4Bedroom.csv
# 34   ./Zip_2/Zip_MedianRentalPrice_5BedroomOrMore.csv
# 35         ./Zip_2/Zip_MedianRentalPrice_AllHomes.csv
# 36        ./Zip_2/Zip_MedianRentalPrice_CondoCoop.csv
# 37    ./Zip_2/Zip_MedianRentalPrice_DuplexTriplex.csv
# 38         ./Zip_2/Zip_MedianRentalPrice_Mfr5Plus.csv
# 39              ./Zip_2/Zip_MedianRentalPrice_Sfr.csv
# 40           ./Zip_2/Zip_MedianRentalPrice_Studio.csv
# 41  ./Zip_2/Zip_MedianRentalPricePerSqft_1Bedroom.csv
# 42  ./Zip_2/Zip_MedianRentalPricePerSqft_2Bedroom.csv
# 43  ./Zip_2/Zip_MedianRentalPricePerSqft_3Bedroom.csv
# 44  ./Zip_2/Zip_MedianRentalPricePerSqft_4Bedroom.csv
# 45  ./Zip_2/Zip_MedianRentalPricePerSqft_5BedroomO...
# 46  ./Zip_2/Zip_MedianRentalPricePerSqft_AllHomes.csv
# 47  ./Zip_2/Zip_MedianRentalPricePerSqft_CondoCoop...
# 48  ./Zip_2/Zip_MedianRentalPricePerSqft_DuplexTri...
# 49  ./Zip_2/Zip_MedianRentalPricePerSqft_Mfr5Plus.csv

# %%
df_zillow.to_csv('zillow.csv')

# %%
df_zillow_desc = pd.read_csv('zillow.csv')

# %%
df_zillow_desc.head()
# Out:
#    Unnamed: 0                                         file_names  \
# 0           0                   ./Zip_2/BuyerSellerIndex_Zip.csv
# 1           1        ./Zip_2/InventoryMeasure_SSA_Zip_Public.csv
# 2           2            ./Zip_2/InventoryMeasure_Zip_Public.csv
# 3           3  ./Zip_2/Zip_Listings_PriceCut_SeasAdj_AllHomes...
# 4           4  ./Zip_2/Zip_Listings_PriceCut_SeasAdj_Condomin...
#
#                                                 Desc
# 0  'Buyer/Seller Index: This index combines the s...
# 1                                                '0’
# 2                                                '0’
# 3  'listings with price cut all homes seasonally ...
# 4        'seasonally adjusted price cuts for condos’

# %%
read_data_list_2[0]['CBSA Title'].unique()
# Out:
# array(['"Akron, OH"', '"Albany-Schenectady-Troy, NY"', '"Albuquerque, NM"',
#        '"Allentown-Bethlehem-Easton, PA-NJ"', '"Amarillo, TX"',
#        '"Anchorage, AK"', '"Ann Arbor, MI"', '"Asheville, NC"',
#        '"Atlanta-Sandy Springs-Roswell, GA"',
#        '"Atlantic City-Hammonton, NJ"', '"Augusta-Richmond County, GA-SC"',
#        '"Austin-Round Rock, TX"', '"Bakersfield, CA"',
#        '"Baltimore-Columbia-Towson, MD"', '"Barnstable Town, MA"',
#        '"Baton Rouge, LA"', '"Beaumont-Port Arthur, TX"',
#        '"Birmingham-Hoover, AL"', '"Boise City, ID"',
#        '"Boston-Cambridge-Newton, MA-NH"',
#        '"Bridgeport-Stamford-Norwalk, CT"',
#        '"Buffalo-Cheektowaga-Niagara Falls, NY"', '"Canton-Massillon, OH"',
#        '"Cape Coral-Fort Myers, FL"', '"Champaign-Urbana, IL"',
#        '"Charleston-North Charleston, SC"',
#        '"Charlotte-Concord-Gastonia, NC-SC"', '"Chattanooga, TN-GA"',
#        '"Chicago-Naperville-Elgin, IL-IN-WI"', '"Cincinnati, OH-KY-IN"',
#        '"Claremont-Lebanon, NH-VT"', '"Cleveland-Elyria, OH"',
#        '"Colorado Springs, CO"', '"Columbia, SC"', '"Columbus, OH"',
#        '"Corpus Christi, TX"', '"Dallas-Fort Worth-Arlington, TX"',
#        '"Daphne-Fairhope-Foley, AL"', '"Dayton, OH"',
#        '"Deltona-Daytona Beach-Ormond Beach, FL"',
#        '"Denver-Aurora-Lakewood, CO"', '"Des Moines-West Des Moines, IA"',
#        '"Detroit-Warren-Dearborn, MI"', '"Durham-Chapel Hill, NC"',
#        '"East Stroudsburg, PA"', '"El Paso, TX"', '"Erie, PA"',
#        '"Eugene, OR"', '"Evansville, IN-KY"', '"Fayetteville, NC"',
#        '"Fayetteville-Springdale-Rogers, AR-MO"', '"Flint, MI"',
#        '"Fort Collins, CO"', '"Fort Wayne, IN"', '"Fresno, CA"',
#        '"Gainesville, FL"', '"Grand Rapids-Wyoming, MI"',
#        '"Greenville-Anderson-Mauldin, SC"',
#        '"Gulfport-Biloxi-Pascagoula, MS"',
#        '"Hagerstown-Martinsburg, MD-WV"', '"Harrisburg-Carlisle, PA"',
#        '"Hartford-West Hartford-East Hartford, CT"',
#        '"Hickory-Lenoir-Morganton, NC"',
#        '"Hilton Head Island-Bluffton-Beaufort, SC"',
#        '"Homosassa Springs, FL"', '"Houston-The Woodlands-Sugar Land, TX"',
#        '"Huntsville, AL"', '"Indianapolis-Carmel-Anderson, IN"',
#        '"Jackson, MS"', '"Jacksonville, FL"', '"Kalamazoo-Portage, MI"',
#        '"Kansas City, MO-KS"', '"Killeen-Temple, TX"',
#        '"Kingsport-Bristol-Bristol, TN-VA"', '"Kingston, NY"',
#        '"Knoxville, TN"', '"Lakeland-Winter Haven, FL"', '"Lancaster, PA"',
#        '"Lansing-East Lansing, MI"', '"Las Vegas-Henderson-Paradise, NV"',
#        '"Lexington-Fayette, KY"',
#        '"Little Rock-North Little Rock-Conway, AR"',
#        '"Louisville/Jefferson County, KY-IN"', '"Madison, WI"',
#        '"Manchester-Nashua, NH"', '"McAllen-Edinburg-Mission, TX"',
#        '"Memphis, TN-MS-AR"',
#        '"Miami-Fort Lauderdale-West Palm Beach, FL"',
#        '"Milwaukee-Waukesha-West Allis, WI"',
#        '"Minneapolis-St. Paul-Bloomington, MN-WI"', '"Mobile, AL"',
#        '"Modesto, CA"', '"Montgomery, AL"',
#        '"Myrtle Beach-Conway-North Myrtle Beach, SC-NC"',
#        '"Naples-Immokalee-Marco Island, FL"',
#        '"Nashville-Davidson--Murfreesboro--Franklin, TN"',
#        '"New Haven-Milford, CT"', '"New Orleans-Metairie, LA"',
#        '"New York-Newark-Jersey City, NY-NJ-PA"',
#        '"Niles-Benton Harbor, MI"', '"Norwich-New London, CT"',
#        '"Ocala, FL"', '"Ocean City, NJ"', '"Ogden-Clearfield, UT"',
#        '"Oklahoma City, OK"', '"Omaha-Council Bluffs, NE-IA"',
#        '"Orlando-Kissimmee-Sanford, FL"',
#        '"Oxnard-Thousand Oaks-Ventura, CA"',
#        '"Palm Bay-Melbourne-Titusville, FL"',
#        '"Pensacola-Ferry Pass-Brent, FL"', '"Peoria, IL"',
#        '"Philadelphia-Camden-Wilmington, PA-NJ-DE-MD"',
#        '"Phoenix-Mesa-Scottsdale, AZ"', '"Pittsburgh, PA"',
#        '"Port St. Lucie, FL"', '"Portland-South Portland, ME"',
#        '"Portland-Vancouver-Hillsboro, OR-WA"', '"Prescott, AZ"',
#        '"Providence-Warwick, RI-MA"', '"Provo-Orem, UT"',
#        '"Punta Gorda, FL"', '"Raleigh, NC"', '"Reading, PA"', '"Reno, NV"',
#        '"Richmond, VA"', '"Riverside-San Bernardino-Ontario, CA"',
#        '"Roanoke, VA"', '"Rochester, NY"', '"Rockford, IL"',
#        '"Sacramento--Roseville--Arden-Arcade, CA"', '"Salem, OR"',
#        '"Salisbury, MD-DE"', '"Salt Lake City, UT"',
#        '"San Antonio-New Braunfels, TX"', '"San Diego-Carlsbad, CA"',
#        '"San Francisco-Oakland-Hayward, CA"',
#        '"San Jose-Sunnyvale-Santa Clara, CA"',
#        '"San Luis Obispo-Paso Robles-Arroyo Grande, CA"',
#        '"Santa Rosa, CA"', '"Savannah, GA"',
#        '"Scranton--Wilkes-Barre--Hazleton, PA"',
#        '"Seattle-Tacoma-Bellevue, WA"', '"Shreveport-Bossier City, LA"',
#        '"South Bend-Mishawaka, IN-MI"', '"Spartanburg, SC"',
#        '"Spokane-Spokane Valley, WA"', '"Springfield, MA"',
#        '"Springfield, MO"', '"St. Louis, MO-IL"', '"Stockton-Lodi, CA"',
#        '"Syracuse, NY"', '"Tallahassee, FL"',
#        '"Tampa-St. Petersburg-Clearwater, FL"', '"Toledo, OH"',
#        '"Trenton, NJ"', '"Tucson, AZ"', '"Tulsa, OK"',
#        '"Virginia Beach-Norfolk-Newport News, VA-NC"',
#        '"Washington-Arlington-Alexandria, DC-VA-MD-WV"', '"Wichita, KS"',
#        '"Wilmington, NC"', '"Winston-Salem, NC"', '"Worcester, MA-CT"',
#        '"York-Hanover, PA"', '"Youngstown-Warren-Boardman, OH-PA"',
#        '"Crestview-Fort Walton Beach-Destin, FL"',
#        '"Los Angeles-Long Beach-Anaheim, CA"',
#        '"North Port-Sarasota-Bradenton, FL"',
#        '"Santa Maria-Santa Barbara, CA"', '"Urban Honolulu, HI"'], dtype=object)

# %%
list_of_file_names_metro = glob.glob("./Metro/*.csv")

# %%
list_of_file_names_neighborhood = glob.glob("./Neighborhood/*.csv")

# %%
read_data_list_3 = []
fail_list_3 = []
for i, data in enumerate(list_of_file_names_metro):
    try:
        data = pd.read_csv(data)
        #data = unicode(data, errors='replace')
        read_data_list_3.append(data)
    except UnicodeDecodeError:
        fail_list_3.append(i)
#read_data_list
#fail_list_3
list_of_file_names_org_3 = list_of_file_names_metro

# %%
read_data_list_4 = []
fail_list_4 = []
for i, data in enumerate(list_of_file_names_neighborhood):
    try:
        data = pd.read_csv(data)
        #data = unicode(data, errors='replace')
        read_data_list_4.append(data)
    except UnicodeDecodeError:
        fail_list_4.append(i)
#read_data_list
#fail_list_3
list_of_file_names_org_4 = list_of_file_names_neighborhood

# %%
for x in fail_list_3:
    del list_of_file_names_metro[x]

# %%
for x in fail_list_4:
    del list_of_file_names_neighborhood[x]

# %%
len(list_of_file_names_metro)
# Out:
# 97

# %%
len(read_data_list_3)
# Out:
# 97

# %%
len(list_of_file_names_neighborhood)
# Out:
# 82

# %%
len(read_data_list_4)
# Out:
# 82

# %%
df_zillow_metro = pd.DataFrame()
df_zillow_metro['file_names'] = list_of_file_names_metro
df_zillow_metro.head(10)
# Out:
#                                           file_names
# 0            ./Metro/AgeOfInventory_Metro_Public.csv
# 1              ./Metro/DaysOnZillow_Public_Metro.csv
# 2          ./Metro/InventoryMeasure_Metro_Public.csv
# 3      ./Metro/InventoryMeasure_SSA_Metro_Public.csv
# 4    ./Metro/InventoryMeasure_Tiers_Metro_Public.csv
# 5                ./Metro/MarketHealthIndex_Metro.csv
# 6  ./Metro/Metro_Listings_PriceCut_SeasAdj_AllHom...
# 7  ./Metro/Metro_Listings_PriceCut_SeasAdj_Bottom...
# 8  ./Metro/Metro_Listings_PriceCut_SeasAdj_Condom...
# 9  ./Metro/Metro_Listings_PriceCut_SeasAdj_Middle...

# %%
df_zillow_neighborhood = pd.DataFrame()
df_zillow_neighborhood['file_names'] = list_of_file_names_neighborhood
df_zillow_neighborhood.head(10)
# Out:
#                                           file_names
# 0  ./Neighborhood/InventoryMeasure_Neighborhood_P...
# 1  ./Neighborhood/InventoryMeasure_SSA_Neighborho...
# 2  ./Neighborhood/Neighborhood_Listings_PriceCut_...
# 3  ./Neighborhood/Neighborhood_Listings_PriceCut_...
# 4  ./Neighborhood/Neighborhood_Listings_PriceCut_...
# 5  ./Neighborhood/Neighborhood_Median_PriceCut_Do...
# 6  ./Neighborhood/Neighborhood_Median_PriceCut_Do...
# 7  ./Neighborhood/Neighborhood_Median_PriceCut_Do...
# 8  ./Neighborhood/Neighborhood_MedianListingPrice...
# 9  ./Neighborhood/Neighborhood_MedianListingPrice...

# %%
columns_1 = read_data_list[5].columns
list(columns_1)
# Out:
# ['RegionID',
#  'RegionName',
#  'City',
#  'State',
#  'Metro',
#  'CountyName',
#  'SizeRank',
#  '1996-04',
#  '1996-05',
#  '1996-06',
#  '1996-07',
#  '1996-08',
#  '1996-09',
#  '1996-10',
#  '1996-11',
#  '1996-12',
#  '1997-01',
#  '1997-02',
#  '1997-03',
#  '1997-04',
#  '1997-05',
#  '1997-06',
#  '1997-07',
#  '1997-08',
#  '1997-09',
#  '1997-10',
#  '1997-11',
#  '1997-12',
#  '1998-01',
#  '1998-02',
#  '1998-03',
#  '1998-04',
#  '1998-05',
#  '1998-06',
#  '1998-07',
#  '1998-08',
#  '1998-09',
#  '1998-10',
#  '1998-11',
#  '1998-12',
#  '1999-01',
#  '1999-02',
#  '1999-03',
#  '1999-04',
#  '1999-05',
#  '1999-06',
#  '1999-07',
#  '1999-08',
#  '1999-09',
#  '1999-10',
#  '1999-11',
#  '1999-12',
#  '2000-01',
#  '2000-02',
#  '2000-03',
#  '2000-04',
#  '2000-05',
#  '2000-06',
#  '2000-07',
#  '2000-08',
#  '2000-09',
#  '2000-10',
#  '2000-11',
#  '2000-12',
#  '2001-01',
#  '2001-02',
#  '2001-03',
#  '2001-04',
#  '2001-05',
#  '2001-06',
#  '2001-07',
#  '2001-08',
#  '2001-09',
#  '2001-10',
#  '2001-11',
#  '2001-12',
#  '2002-01',
#  '2002-02',
#  '2002-03',
#  '2002-04',
#  '2002-05',
#  '2002-06',
#  '2002-07',
#  '2002-08',
#  '2002-09',
#  '2002-10',
#  '2002-11',
#  '2002-12',
#  '2003-01',
#  '2003-02',
#  '2003-03',
#  '2003-04',
#  '2003-05',
#  '2003-06',
#  '2003-07',
#  '2003-08',
#  '2003-09',
#  '2003-10',
#  '2003-11',
#  '2003-12',
#  '2004-01',
#  '2004-02',
#  '2004-03',
#  '2004-04',
#  '2004-05',
#  '2004-06',
#  '2004-07',
#  '2004-08',
#  '2004-09',
#  '2004-10',
#  '2004-11',
#  '2004-12',
#  '2005-01',
#  '2005-02',
#  '2005-03',
#  '2005-04',
#  '2005-05',
#  '2005-06',
#  '2005-07',
#  '2005-08',
#  '2005-09',
#  '2005-10',
#  '2005-11',
#  '2005-12',
#  '2006-01',
#  '2006-02',
#  '2006-03',
#  '2006-04',
#  '2006-05',
#  '2006-06',
#  '2006-07',
#  '2006-08',
#  '2006-09',
#  '2006-10',
#  '2006-11',
#  '2006-12',
#  '2007-01',
#  '2007-02',
#  '2007-03',
#  '2007-04',
#  '2007-05',
#  '2007-06',
#  '2007-07',
#  '2007-08',
#  '2007-09',
#  '2007-10',
#  '2007-11',
#  '2007-12',
#  '2008-01',
#  '2008-02',
#  '2008-03',
#  '2008-04',
#  '2008-05',
#  '2008-06',
#  '2008-07',
#  '2008-08',
#  '2008-09',
#  '2008-10',
#  '2008-11',
#  '2008-12',
#  '2009-01',
#  '2009-02',
#  '2009-03',
#  '2009-04',
#  '2009-05',
#  '2009-06',
#  '2009-07',
#  '2009-08',
#  '2009-09',
#  '2009-10',
#  '2009-11',
#  '2009-12',
#  '2010-01',
#  '2010-02',
#  '2010-03',
#  '2010-04',
#  '2010-05',
#  '2010-06',
#  '2010-07',
#  '2010-08',
#  '2010-09',
#  '2010-10',
#  '2010-11',
#  '2010-12',
#  '2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-10',
#  '2013-11',
#  '2013-12',
#  '2014-01',
#  '2014-02',
#  '2014-03',
#  '2014-04',
#  '2014-05',
#  '2014-06',
#  '2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-10',
#  '2014-11',
#  '2014-12',
#  '2015-01',
#  '2015-02',
#  '2015-03',
#  '2015-04',
#  '2015-05',
#  '2015-06',
#  '2015-07',
#  '2015-08',
#  '2015-09',
#  '2015-10',
#  '2015-11',
#  '2015-12',
#  '2016-01',
#  '2016-02',
#  '2016-03',
#  '2016-04',
#  '2016-05',
#  '2016-06',
#  '2016-07',
#  '2016-08',
#  '2016-09',
#  '2016-10',
#  '2016-11',
#  '2016-12',
#  '2017-01',
#  '2017-02',
#  '2017-03',
#  '2017-04',
#  '2017-05',
#  '2017-06',
#  '2017-07',
#  '2017-08',
#  '2017-09',
#  '2017-10',
#  '2017-11',
#  '2017-12']

# %%
#read_data_list[0].dropna()
read_data_list[5].nunique()
# Out:
# RegionID      15437
# RegionName    15437
# City           8271
# State            51
# Metro           728
# CountyName     1241
# SizeRank      15437
# 1996-04        2361
# 1996-05        2358
# 1996-06        2360
# 1996-07        2377
# 1996-08        2371
# 1996-09        2376
# 1996-10        2393
# 1996-11        2379
# 1996-12        2370
# 1997-01        2390
# 1997-02        2447
# 1997-03        2470
# 1997-04        2466
# 1997-05        2476
# 1997-06        2483
# 1997-07        2485
# 1997-08        2503
# 1997-09        2499
# 1997-10        2524
# 1997-11        2524
# 1997-12        2542
# 1998-01        2536
# 1998-02        2586
#               ...
# 2015-07        4651
# 2015-08        4666
# 2015-09        4697
# 2015-10        4705
# 2015-11        4738
# 2015-12        4753
# 2016-01        4767
# 2016-02        4760
# 2016-03        4797
# 2016-04        4790
# 2016-05        4792
# 2016-06        4832
# 2016-07        4826
# 2016-08        4853
# 2016-09        4899
# 2016-10        4875
# 2016-11        4893
# 2016-12        4896
# 2017-01        4933
# 2017-02        4933
# 2017-03        4933
# 2017-04        4959
# 2017-05        4978
# 2017-06        4975
# 2017-07        4984
# 2017-08        5001
# 2017-09        5003
# 2017-10        5001
# 2017-11        5047
# 2017-12        5021
# Length: 268, dtype: int64

# %%
# Region name is zip code
read_data_list[5].sort_values('RegionName',ascending=False)
# Out:
#        RegionID  RegionName                 City State            Metro  \
# 7290     100478       99901            Ketchikan    AK        Ketchikan
# 4083     100459       99801               Juneau    AK           Juneau
# 8585     100387       99712            Fairbanks    AK        Fairbanks
# 4548     100384       99709            Fairbanks    AK        Fairbanks
# 5522     100380       99705           North Pole    AK        Fairbanks
# 5923     100376       99701            Fairbanks    AK        Fairbanks
# 11152    100344       99664               Seward    AK              NaN
# 3925     100334       99654              Tanaina    AK        Anchorage
# 4195     100326       99645               Palmer    AK        Anchorage
# 7236     100301       99615               Kodiak    AK              NaN
# 7153     100297       99611                Kenai    AK              NaN
# 4181     100274       99577            Anchorage    AK        Anchorage
# 9100     100265       99567            Anchorage    AK        Anchorage
# 13344    100256       99556         Anchor Point    AK              NaN
# 8386     100236       99518            Anchorage    AK        Anchorage
# 6258     100235       99517            Anchorage    AK        Anchorage
# 6260     100234       99516            Anchorage    AK        Anchorage
# 5543     100233       99515            Anchorage    AK        Anchorage
# 2664     100227       99508            Anchorage    AK        Anchorage
# 2063     100226       99507            Anchorage    AK        Anchorage
# 1627     100223       99504            Anchorage    AK        Anchorage
# 6692     100222       99503            Anchorage    AK        Anchorage
# 4851     100221       99502            Anchorage    AK        Anchorage
# 5434     100220       99501            Anchorage    AK        Anchorage
# 1274     100214       99362          Walla Walla    WA      Walla Walla
# 4650     100208       99354             Richland    WA        Kennewick
# 6820     100207       99353        West Richland    WA        Kennewick
# 2012     100206       99352             Richland    WA        Kennewick
# 7752     100205       99350              Prosser    WA        Kennewick
# 11318    100204       99349              Mattawa    WA       Moses Lake
# ...         ...         ...                  ...   ...              ...
# 14977     58242        1071              Russell    MA      Springfield
# 8875      58240        1069       Town of Palmer    MA      Springfield
# 14580     58239        1068               Oakham    MA        Worcester
# 7844      58236        1062          Northampton    MA      Springfield
# 6159      58234        1060          Northampton    MA      Springfield
# 9253      58232        1057               Monson    MA      Springfield
# 5140      58231        1056               Ludlow    MA      Springfield
# 14291     58230        1054             Leverett    MA  Greenfield Town
# 14372     58229        1053          Northampton    MA      Springfield
# 13345     58228        1050           Huntington    MA      Springfield
# 1634      58226        1040              Holyoke    MA      Springfield
# 13260     58224        1038     Town of Hatfield    MA      Springfield
# 11234     58222        1036              Hampden    MA      Springfield
# 10570     58221        1035               Hadley    MA      Springfield
# 14102     58220        1034              Tolland    MA      Springfield
# 10208     58219        1033       Town of Granby    MA      Springfield
# 7829      58216        1030               Agawam    MA      Springfield
# 6509      58214        1028      East Longmeadow    MA      Springfield
# 5139      58213        1027          Easthampton    MA      Springfield
# 15200     58212        1026           Cummington    MA      Springfield
# 13337     58211        1022             Chicopee    MA      Springfield
# 2560      58209        1020             Chicopee    MA      Springfield
# 4433      58207        1013             Chicopee    MA      Springfield
# 15094     58205        1011              Chester    MA      Springfield
# 12053     58204        1010            Brimfield    MA      Springfield
# 15144     58202        1008            Blandford    MA      Springfield
# 6863      58201        1007  Town of Belchertown    MA      Springfield
# 11467     58200        1005        Town of Barre    MA        Worcester
# 4130      58197        1002              Amherst    MA      Springfield
# 5782      58196        1001               Agawam    MA      Springfield
#
#                  CountyName  SizeRank   1996-04   1996-05   1996-06   ...     \
# 7290      Ketchikan Gateway      7291  221900.0  221900.0  221900.0   ...
# 4083                 Juneau      4084       NaN       NaN       NaN   ...
# 8585   Fairbanks North Star      8586       NaN       NaN       NaN   ...
# 4548   Fairbanks North Star      4549       NaN       NaN       NaN   ...
# 5522   Fairbanks North Star      5523       NaN       NaN       NaN   ...
# 5923   Fairbanks North Star      5924       NaN       NaN       NaN   ...
# 11152       Kenai Peninsula     11153       NaN       NaN       NaN   ...
# 3925      Matanuska Susitna      3926       NaN       NaN       NaN   ...
# 4195      Matanuska Susitna      4196       NaN       NaN       NaN   ...
# 7236          Kodiak Island      7237  260900.0  260900.0  260900.0   ...
# 7153        Kenai Peninsula      7154       NaN       NaN       NaN   ...
# 4181              Anchorage      4182       NaN       NaN       NaN   ...
# 9100              Anchorage      9101       NaN       NaN       NaN   ...
# 13344       Kenai Peninsula     13345       NaN       NaN       NaN   ...
# 8386              Anchorage      8387       NaN       NaN       NaN   ...
# 6258              Anchorage      6259       NaN       NaN       NaN   ...
# 6260              Anchorage      6261       NaN       NaN       NaN   ...
# 5543              Anchorage      5544       NaN       NaN       NaN   ...
# 2664              Anchorage      2665       NaN       NaN       NaN   ...
# 2063              Anchorage      2064       NaN       NaN       NaN   ...
# 1627              Anchorage      1628       NaN       NaN       NaN   ...
# 6692              Anchorage      6693       NaN       NaN       NaN   ...
# 4851              Anchorage      4852       NaN       NaN       NaN   ...
# 5434              Anchorage      5435       NaN       NaN       NaN   ...
# 1274            Walla Walla      1275  102200.0  103100.0  104400.0   ...
# 4650                 Benton      4651  105800.0  108300.0  108700.0   ...
# 6820                 Benton      6821  116300.0  115800.0  114600.0   ...
# 2012                 Benton      2013  130000.0  134000.0  136500.0   ...
# 7752                 Benton      7753   83100.0   84000.0   84800.0   ...
# 11318                 Grant     11319       NaN       NaN       NaN   ...
# ...                     ...       ...       ...       ...       ...   ...
# 14977               Hampden     14978  105500.0  104800.0  104600.0   ...
# 8875                Hampden      8876   94800.0   95600.0   96600.0   ...
# 14580             Worcester     14581  125600.0  126400.0  127600.0   ...
# 7844              Hampshire      7845  118400.0  117700.0  117000.0   ...
# 6159              Hampshire      6160  112600.0  112000.0  112400.0   ...
# 9253                Hampden      9254  105700.0  107000.0  108400.0   ...
# 5140                Hampden      5141  102800.0  104200.0  105400.0   ...
# 14291              Franklin     14292  137600.0  135000.0  135400.0   ...
# 14372             Hampshire     14373  124000.0  123600.0  123400.0   ...
# 13345             Hampshire     13346  107700.0  107500.0  107500.0   ...
# 1634                Hampden      1635   83200.0   83600.0   83600.0   ...
# 13260             Hampshire     13261       NaN       NaN       NaN   ...
# 11234               Hampden     11235  123300.0  123400.0  123800.0   ...
# 10570             Hampshire     10571  144100.0  146000.0  147600.0   ...
# 14102               Hampden     14103  136800.0  137400.0  138800.0   ...
# 10208             Hampshire     10209  109700.0  111900.0  113900.0   ...
# 7829                Hampden      7830  114600.0  115800.0  116600.0   ...
# 6509                Hampden      6510  121600.0  123600.0  125100.0   ...
# 5139              Hampshire      5140  111800.0  111300.0  111200.0   ...
# 15200             Hampshire     15201  114900.0  115200.0  116400.0   ...
# 13337               Hampden     13338       NaN       NaN       NaN   ...
# 2560                Hampden      2561   93400.0   93700.0   93600.0   ...
# 4433                Hampden      4434   80500.0   81400.0   82500.0   ...
# 15094               Hampden     15095   85200.0   85000.0   85200.0   ...
# 12053               Hampden     12054  112000.0  113400.0  114600.0   ...
# 15144               Hampden     15145  109300.0  108500.0  108700.0   ...
# 6863              Hampshire      6864  124000.0  124800.0  125600.0   ...
# 11467             Worcester     11468  101200.0  101700.0  102400.0   ...
# 4130              Hampshire      4131  135200.0  135300.0  136400.0   ...
# 5782                Hampden      5783  101900.0  102800.0  103200.0   ...
#
#        2017-03  2017-04  2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  \
# 7290    235200   243000   246000   242300   239600   238600   238600   238600
# 4083    323100   324800   327400   330400   333500   335700   336500   338100
# 8585    243300   243200   244200   246500   249300   251300   252600   253900
# 4548    231200   231100   230800   231000   232100   233400   234700   236300
# 5522    213200   213500   213500   213800   214200   214900   216500   218400
# 5923    180000   179900   180400   181800   183000   183900   184900   186100
# 11152   218900   220100   220200   220900   222100   223500   224400   224900
# 3925    240700   239700   238700   238300   238300   238800   239900   240600
# 4195    248900   248000   247400   247100   247400   248400   249800   250500
# 7236    273200   273600   274000   274600   275400   276200   276800   277900
# 7153    205200   205200   205900   206500   206700   206600   205900   205600
# 4181    316200   317600   319700   321000   321600   322300   323000   323900
# 9100    340200   341200   341800   341900   341200   341000   342400   345800
# 13344   176100   174900   175900   178800   181200   181100   181300   182400
# 8386    231500   232000   232800   232800   232100   231900   231800   231900
# 6258    284900   285600   285500   285000   284800   284600   284700   285100
# 6260    448000   449500   450600   449900   448800   448500   448500   448600
# 5543    321900   322000   323000   323600   323500   323500   323400   324000
# 2664    243500   243300   243400   244100   244700   245200   245800   246400
# 2063    285900   286000   286400   286900   287300   287900   288800   289900
# 1627    259900   259700   259800   260300   260300   260300   260900   261600
# 6692    237100   236800   236700   237200   237600   237800   237100   237300
# 4851    297700   298700   298600   298500   298100   297500   297400   297000
# 5434    245300   245300   245300   244900   244800   245700   247600   249500
# 1274    220200   222600   224600   226800   228500   230200   232200   233900
# 4650    217500   222400   227300   230700   232000   232700   232800   235000
# 6820    264500   267900   271100   273600   276400   278000   276900   277300
# 2012    275400   278600   281600   284100   286000   286900   286500   287600
# 7752    184900   186600   188200   189600   191500   192900   192700   192600
# 11318   151400   152600   154000   156100   158300   160200   160600   160000
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14977   217100   218500   219600   220600   222100   224700   228900   231400
# 8875    172700   173500   174100   175600   178000   180000   183000   187600
# 14580   275300   277100   278600   278100   277600   278500   279100   280000
# 7844    266900   267500   268800   269700   268700   268300   269500   271300
# 6159    275600   277100   278800   279700   278400   277600   278700   280300
# 9253    223500   225600   227200   228700   230000   231200   232800   235200
# 5140    208000   209300   210400   211000   211500   212200   213500   214800
# 14291   314400   316600   315100   312900   312100   312300   313100   314300
# 14372   251700   251800   253400   255000   255300   254800   254000   253700
# 13345   207600   209800   212900   215100   216700   218400   218400   217900
# 1634    174600   175700   177100   178600   179800   181200   183400   185200
# 13260   292200   293700   296700   300400   302200   302500   303100   304500
# 11234   257900   259300   260400   261100   261800   263300   266900   270100
# 10570   318200   319600   321800   322500   322000   321500   320900   320500
# 14102   255700   255800   255200   255500   257300   259000   261000   262300
# 10208   231600   232100   233300   234000   232800   232400   233600   234900
# 7829    230900   232500   234200   235000   235600   236200   237000   237300
# 6509    238000   239000   240000   240200   241200   243300   246900   249900
# 5139    237000   238200   239500   240000   238800   237700   238600   240200
# 15200   230700   229000   229000   229000   227600   226900   227700   228100
# 13337   112500   112100   112400   112800   112500   112100   112400   113100
# 2560    175200   176200   177500   178400   179200   180400   182500   183900
# 4433    167700   169000   170400   170900   170900   171300   172600   173800
# 15094   167400   167900   168000   169000   171500   173400   174900   176500
# 12053   238700   240900   243400   245300   246300   247700   248900   249100
# 15144   217100   219800   221900   222300   222800   224400   227600   230900
# 6863    264100   264100   264700   264900   263900   263500   264600   265100
# 11467   225700   222100   219600   219000   219000   219300   220800   221700
# 4130    313600   315700   317900   318700   318000   316800   316700   318000
# 5782    195300   195900   197100   197600   197600   198400   200800   203100
#
#        2017-11  2017-12
# 7290    242600   249500
# 4083    341100   342600
# 8585    255100   255900
# 4548    238300   239600
# 5522    220500   222500
# 5923    186900   187500
# 11152   226300   228200
# 3925    240100   239900
# 4195    250100   250000
# 7236    282500   288200
# 7153    205800   206000
# 4181    326400   329500
# 9100    350000   353900
# 13344   183500   183700
# 8386    232300   232800
# 6258    286300   288200
# 6260    449300   451200
# 5543    326000   328800
# 2664    246700   246800
# 2063    290900   291800
# 1627    262200   263400
# 6692    239000   241100
# 4851    296800   297900
# 5434    250100   250400
# 1274    236000   238500
# 4650    238400   239700
# 6820    279400   279000
# 2012    290300   291100
# 7752    193400   193500
# 11318   160800   162000
# ...        ...      ...
# 14977   231200   230800
# 8875    190800   191400
# 14580   282200   284300
# 7844    273000   274300
# 6159    282000   284300
# 9253    237500   238900
# 5140    215700   216400
# 14291   315100   314900
# 14372   255800   258000
# 13345   218800   220100
# 1634    185500   185500
# 13260   304900   304200
# 11234   271000   271400
# 10570   321300   322300
# 14102   261000   259000
# 10208   235900   236700
# 7829    237400   238000
# 6509    251300   251900
# 5139    242300   244500
# 15200   229400   231200
# 13337   113400   113900
# 2560    184000   183900
# 4433    174300   174600
# 15094   177500   177500
# 12053   248300   247800
# 15144   231300   230000
# 6863    265200   265700
# 11467   222200   223100
# 4130    320300   322100
# 5782    204000   204200
#
# [15437 rows x 268 columns]

# %%
# Create a plot of rows. Needs better legend. Can use this to evaluate any number.
#plot_list = range(7)
def test_plot(read_data_list, plot_list, list_index, column_index):
    plot_slice_list = []
    #plot_label = str(list_index)
    for num in plot_list:
        plot_slice = read_data_list[list_index].iloc[num, column_index:]
        plot_slice_list.append(plot_slice)
    for plot in plot_slice_list:
        plot.plot(legend=True)
test_plot(read_data_list_2, range(3), 28, 6)

# %%
plot_slice = read_data_list[5].iloc[1, 6:]
plot_slice_2 = read_data_list[5].iloc[2, 6:]
plot_slice_us = read_data_list[5].iloc[0, 6:]
#plot_slice.plot()
#plot_slice_2.plot()
print(plot_slice)
# Out:
# SizeRank         2
# 1996-04     146700
# 1996-05     146500
# 1996-06     146300
# 1996-07     146300
# 1996-08     146800
# 1996-09     147100
# 1996-10     147300
# 1996-11     147800
# 1996-12     148600
# 1997-01     149100
# 1997-02     149600
# 1997-03     151100
# 1997-04     153200
# 1997-05     155100
# 1997-06     157200
# 1997-07     159100
# 1997-08     160000
# 1997-09     160800
# 1997-10     162200
# 1997-11     163200
# 1997-12     164100
# 1998-01     165600
# 1998-02     167400
# 1998-03     168000
# 1998-04     168100
# 1998-05     168500
# 1998-06     168900
# 1998-07     169100
# 1998-08     170200
#              ...
# 2015-07     308900
# 2015-08     308400
# 2015-09     308600
# 2015-10     310400
# 2015-11     311400
# 2015-12     310700
# 2016-01     311100
# 2016-02     312300
# 2016-03     314100
# 2016-04     316100
# 2016-05     316600
# 2016-06     316600
# 2016-07     316700
# 2016-08     317100
# 2016-09     316500
# 2016-10     316300
# 2016-11     317000
# 2016-12     318500
# 2017-01     318900
# 2017-02     319700
# 2017-03     321100
# 2017-04     322900
# 2017-05     324500
# 2017-06     325100
# 2017-07     324300
# 2017-08     324000
# 2017-09     324600
# 2017-10     324500
# 2017-11     322600
# 2017-12     321600
# Name: 1, Length: 262, dtype: object

# %%
plot_slice.values
# Out:
# array([2, 146700.0, 146500.0, 146300.0, 146300.0, 146800.0, 147100.0,
#        147300.0, 147800.0, 148600.0, 149100.0, 149600.0, 151100.0,
#        153200.0, 155100.0, 157200.0, 159100.0, 160000.0, 160800.0,
#        162200.0, 163200.0, 164100.0, 165600.0, 167400.0, 168000.0,
#        168100.0, 168500.0, 168900.0, 169100.0, 170200.0, 172100.0,
#        174500.0, 177100.0, 180500.0, 183200.0, 184900.0, 187100.0,
#        189800.0, 191300.0, 192000.0, 193200.0, 195000.0, 197100.0,
#        200100.0, 203100.0, 204800.0, 206100.0, 207900.0, 209900.0,
#        212700.0, 216600.0, 219900.0, 223500.0, 227100.0, 229100.0,
#        230300.0, 233000.0, 236200.0, 239700.0, 242900.0, 245400.0,
#        248000.0, 250400.0, 252600.0, 254300.0, 257300.0, 261400.0,
#        265100.0, 266200.0, 266500.0, 267100.0, 268000.0, 269000.0,
#        269500.0, 269800.0, 270400.0, 272700.0, 276300.0, 279300.0,
#        281900.0, 284600.0, 285400.0, 285200.0, 286200.0, 288900.0,
#        291800.0, 295100.0, 298600.0, 300200.0, 299100.0, 298000.0,
#        296300.0, 294200.0, 292700.0, 292500.0, 293600.0, 295100.0,
#        295800.0, 296000.0, 296900.0, 297800.0, 297800.0, 297900.0,
#        298300.0, 299100.0, 302400.0, 307200.0, 309900.0, 311000.0,
#        311000.0, 311300.0, 311900.0, 312600.0, 313300.0, 314600.0,
#        315900.0, 318000.0, 320700.0, 322300.0, 322300.0, 321200.0,
#        320800.0, 320500.0, 319700.0, 319000.0, 318800.0, 318100.0,
#        317900.0, 318300.0, 318000.0, 318000.0, 318700.0, 319200.0,
#        319400.0, 320700.0, 321500.0, 322400.0, 323900.0, 324500.0,
#        324000.0, 323300.0, 322500.0, 322500.0, 323300.0, 323300.0,
#        322800.0, 321300.0, 319600.0, 318300.0, 316900.0, 315400.0,
#        314500.0, 313500.0, 312700.0, 312200.0, 311800.0, 311300.0,
#        310400.0, 308100.0, 307000.0, 306800.0, 305600.0, 304500.0,
#        304800.0, 305300.0, 302700.0, 296100.0, 289800.0, 287200.0,
#        286000.0, 285000.0, 283600.0, 281400.0, 279500.0, 277700.0,
#        274900.0, 272200.0, 272200.0, 273400.0, 274200.0, 271800.0,
#        268000.0, 266200.0, 266200.0, 264300.0, 262600.0, 262600.0,
#        262000.0, 260400.0, 259500.0, 260500.0, 260900.0, 260000.0,
#        259500.0, 260300.0, 260800.0, 261200.0, 262900.0, 264400.0,
#        266300.0, 268300.0, 269000.0, 268800.0, 270200.0, 273000.0,
#        278000.0, 283300.0, 286200.0, 288100.0, 289000.0, 289500.0,
#        290000.0, 291000.0, 291700.0, 293100.0, 295200.0, 298000.0,
#        297800.0, 295700, 295300, 298400, 301700, 303100, 303600, 305500,
#        307800, 307600, 305400, 305100, 307300, 308700, 308600, 308900,
#        308400, 308600, 310400, 311400, 310700, 311100, 312300, 314100,
#        316100, 316600, 316600, 316700, 317100, 316500, 316300, 317000,
#        318500, 318900, 319700, 321100, 322900, 324500, 325100, 324300,
#        324000, 324600, 324500, 322600, 321600], dtype=object)

# %%
plot_slice.index
# Out:
# Index(['SizeRank', '1996-04', '1996-05', '1996-06', '1996-07', '1996-08',
#        '1996-09', '1996-10', '1996-11', '1996-12',
#        ...
#        '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08',
#        '2017-09', '2017-10', '2017-11', '2017-12'],
#       dtype='object', length=262)

# %%
x = plot_slice.index
y = plot_slice.values

# %%
new_x = datetime.strptime(x[10], "%Y-%m")
new_x
# Out:
# datetime.datetime(1997, 1, 1, 0, 0)

# %%
def convert_time(x, column_num):
    time_list = []
    for time in x[column_num:]:
        time = datetime.strptime(time, "%Y-%m")
        time_list.append(time)
    return time_list
time_list = convert_time(x, 1)

# %%
plt.plot(time_list, y[1:])

# %%
x_2 = plot_slice_2.index
time_list_2 = convert_time(x_2, 1)
y_2 = plot_slice_2.values

# %%
plt.plot(time_list_2, y_2[1:])

# %%
x_us = plot_slice_us.index
time_list_us = convert_time(x_us, 1)
y_us = plot_slice_us.values
plt.plot(time_list_us, y_us[1:])

# %%
import json
with open('./yelp_dataset/business.json') as data_file:    
    data = json.load(data_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-26-0e542f206274> in <module>()
#       1 import json
#       2 with open('./yelp_dataset/business.json') as data_file:
# ----> 3     data = json.load(data_file)
#
# ~/Desktop/Thinkful/anaconda/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# ~/Desktop/Thinkful/anaconda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/Desktop/Thinkful/anaconda/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 2 column 1 (char 654)

# %%
read_data_list_2[28].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     93144       79936   El Paso    TX   El Paso    El Paso         5
#
#    2010-11  2010-12  2011-01   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...       4.364    4.366    4.360    4.354
# 1    1.546    1.554    1.556   ...       1.804    1.808    1.812    1.818
# 2      NaN      NaN      NaN   ...       5.322    5.320    5.322    5.336
# 3    1.690    1.700    1.698   ...       1.970    1.974    1.980    1.988
# 4    0.760    0.760    0.756   ...       0.712    0.712    0.710    0.708
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0    4.348    4.366    4.380    4.400    4.396    4.390
# 1    1.822    1.822    1.822    1.820    1.816    1.810
# 2    5.346    5.360    5.356    5.338    5.302    5.264
# 3    1.992    1.990    1.986    1.978    1.970    1.962
# 4    0.708    0.708    0.710    0.712    0.714    0.714
#
# [5 rows x 93 columns]

# %%
print(28)
print('Average Rent Price, all homes')
print(list_of_file_names[28])
test_plot(read_data_list_2, range(7), 28, 7)
# Out:
# 28
# Average Rent Price, all homes
# ./zillow_zipcode/Zip_ZriPerSqft_AllHomes_rental_values.csv

# %%
read_data_list_2[27].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     93144       79936   El Paso    TX   El Paso    El Paso         5
#
#    2010-11  2010-12  2011-01   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...        3715     3699     3698     3703
# 1   2995.0   3023.0   3025.0   ...        3436     3464     3500     3543
# 2      NaN      NaN      NaN   ...        3909     3867     3856     3861
# 3   4835.0   4887.0   4895.0   ...        5585     5607     5589     5582
# 4   1080.0   1075.0   1071.0   ...         998      998      998      997
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0     3733     3746     3753     3745     3738     3717
# 1     3575     3568     3555     3519     3449     3368
# 2     3917     3955     3993     4000     3980     3930
# 3     5558     5511     5448     5374     5304     5237
# 4      995      993      993      996     1001     1005
#
# [5 rows x 93 columns]

# %%
print(27)
print('Average Rent Price, single family')
print(list_of_file_names[27])
test_plot(read_data_list_2, range(7), 27, 7)
# Out:
# 27
# Average Rent Price, single family
# ./zillow_zipcode/Zip_Zri_SingleFamilyResidenceRental_rental_values.csv

# %%
read_data_list_2[26].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     93144       79936   El Paso    TX   El Paso    El Paso         5
#
#    2010-11  2010-12  2011-01   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...      3545.0   3544.0   3534.0   3523.0
# 1   1683.0   1694.0   1702.0   ...      1839.0   1843.0   1851.0   1861.0
# 2      NaN      NaN      NaN   ...      3808.0   3789.0   3789.0   3797.0
# 3   1934.0   1930.0   1922.0   ...      2032.0   2032.0   2043.0   2064.0
# 4    910.0    918.0    913.0   ...       855.0    853.0    850.0    846.0
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3531.0   3544.0   3566.0   3574.0   3572.0   3551.0
# 1   1869.0   1874.0   1874.0   1872.0   1859.0   1848.0
# 2   3848.0   3898.0   3944.0   3944.0   3918.0   3867.0
# 3   2071.0   2075.0   2077.0   2075.0   2061.0   2038.0
# 4    845.0    844.0    844.0    844.0    848.0    851.0
#
# [5 rows x 93 columns]

# %%
print(26)
print('Average rent price multifamily ')
print(list_of_file_names[26])
test_plot(read_data_list_2, range(7), 26, 7)
# Out:
# 26
# Average rent price multifamily
# ./zillow_zipcode/Zip_Zri_MultiFamilyResidenceRental_rental_values.csv

# %%
read_data_list_2[25].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     93144       79936   El Paso    TX   El Paso    El Paso         5
#
#    2010-11  2010-12  2011-01   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...        3550     3548     3539     3528
# 1   1731.0   1742.0   1749.0   ...        1872     1872     1880     1890
# 2      NaN      NaN      NaN   ...        3815     3795     3792     3801
# 3   2005.0   2013.0   2003.0   ...        2102     2102     2112     2131
# 4   1078.0   1070.0   1063.0   ...         993      992      992      992
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0     3538     3552     3573     3581     3578     3557
# 1     1897     1903     1905     1906     1898     1887
# 2     3850     3901     3946     3949     3923     3873
# 3     2138     2135     2140     2134     2126     2100
# 4      990      986      984      987      993      998
#
# [5 rows x 93 columns]

# %%
print(25)
print('Average rent price all homes plus multifamily')
print(list_of_file_names[25])
test_plot(read_data_list_2, range(7), 25, 7)
# Out:
# 25
# Average rent price all homes plus multifamily
# ./zillow_zipcode/Zip_Zri_AllHomesPlusMultifamily_rental_values.csv

# %%
read_data_list_2[24].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     61637       10023  New York    NY  New York   New York         3
# 3     84616       60614   Chicago    IL   Chicago       Cook         4
# 4     93144       79936   El Paso    TX   El Paso    El Paso         5
#
#    2010-11  2010-12  2011-01   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...        3699     3695     3685     3676
# 1   1862.0   1863.0   1861.0   ...        2079     2069     2073     2085
# 2      NaN      NaN      NaN   ...        3943     3945     3979     4006
# 3   2127.0   2123.0   2108.0   ...        2325     2311     2308     2323
# 4   1081.0   1078.0   1075.0   ...        1001     1001     1000      999
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0     3693     3713     3740     3736     3721     3690
# 1     2094     2100     2105     2108     2100     2088
# 2     4067     4116     4171     4175     4138     4060
# 3     2327     2325     2320     2314     2310     2297
# 4      998      998     1000     1004     1010     1014
#
# [5 rows x 93 columns]

# %%
print(24)
print(list_of_file_names[24])
test_plot(read_data_list_2, range(7), 24, 7)
# Out:
# 24
# ./zillow_zipcode/Zip_Zri_AllHomes_rental_values.csv

# %%
read_data_list_2[23].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     84654       60657   Chicago    IL   Chicago       Cook         1
# 1     84616       60614   Chicago    IL   Chicago       Cook         2
# 2     93144       79936   El Paso    TX   El Paso    El Paso         3
# 3     84640       60640   Chicago    IL   Chicago       Cook         4
# 4     61807       10467  New York    NY  New York      Bronx         5
#
#     1996-04   1996-05   1996-06   ...     2017-03  2017-04  2017-05  2017-06  \
# 0  420800.0  423500.0  426200.0   ...     1087500  1080200  1073700  1064100
# 1  542400.0  546700.0  551700.0   ...     1526300  1527000  1524600  1516600
# 2   70900.0   71200.0   71100.0   ...      114000   113800   114000   114000
# 3  298200.0  297400.0  295300.0   ...      735700   728400   726800   724900
# 4       NaN       NaN       NaN   ...      392700   396300   399100   401000
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0  1052600  1047600  1047700  1047600  1048800  1051600
# 1  1512500  1513700  1513600  1508100  1502300  1496300
# 2   113800   113700   114200   114300   114000   114000
# 3   717200   709400   707700   708300   704800   700900
# 4   403100   405200   407600   408800   409600   410500
#
# [5 rows x 268 columns]

# %%
print(23)
print(list_of_file_names[23])
test_plot(read_data_list_2, range(7), 23, 7)
# Out:
# 23
# ./zillow_zipcode/Zip_Zhvi_SingleFamilyResidence._home_values.csv

# %%
read_data_list_2[22].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     93144       79936   El Paso    TX   El Paso    El Paso         4
# 4     84640       60640   Chicago    IL   Chicago       Cook         5
#
#     1996-04   1996-05   1996-06   ...     2017-03  2017-04  2017-05  2017-06  \
# 0       NaN       NaN       NaN   ...     1117000  1133700  1178800  1240100
# 1  138200.0  137500.0  137200.0   ...      304700   305600   306000   305400
# 2  176900.0  174900.0  173700.0   ...      378900   372900   373500   378900
# 3       NaN       NaN       NaN   ...      138500   138700   139200   139200
# 4   97400.0   96200.0   95300.0   ...      190100   190300   191000   192400
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0  1284600  1294400  1287500  1280700  1257000  1234800
# 1   304900   305300   306200   305900   304100   303100
# 2   382500   381200   380100   374600   365600   361200
# 3   139000   138800   139100   140500   142600   143600
# 4   194700   196600   197300   197200   197700   198700
#
# [5 rows x 268 columns]

# %%
print(22)
print(list_of_file_names[22])
test_plot(read_data_list_2, range(7), 22, 7)
# Out:
# 22
# ./zillow_zipcode/Zip_Zhvi_Condominum_home_values.csv

# %%
read_data_list_2[21].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     93144       79936   El Paso    TX   El Paso    El Paso         4
# 4     84640       60640   Chicago    IL   Chicago       Cook         5
#
#     1996-04   1996-05   1996-06   ...     2017-03  2017-04  2017-05  2017-06  \
# 0       NaN       NaN       NaN   ...     1117200  1135800  1181300  1241800
# 1  146700.0  146500.0  146300.0   ...      321100   322900   324500   325100
# 2  198000.0  195500.0  194200.0   ...      410600   400000   401800   410500
# 3   70800.0   71000.0   71000.0   ...      114800   114700   114800   114500
# 4  102300.0  101300.0  100700.0   ...      205200   204900   204100   204400
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0  1286500  1296500  1288300  1281400  1258800  1237700
# 1   324300   324000   324600   324500   322600   321600
# 2   411000   408400   406800   402700   396000   393600
# 3   114200   114300   114800   114900   114600   114600
# 4   206200   208700   210100   209500   209100   209800
#
# [5 rows x 268 columns]

# %%
print(21)
print(list_of_file_names[21])
test_plot(read_data_list_2, range(7), 21, 7)
# Out:
# 21
# ./zillow_zipcode/Zip_Zhvi_AllHomes_Home_Values.csv

# %%
read_data_list_2[20].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     93144       79936   El Paso    TX   El Paso    El Paso         4
# 4     84640       60640   Chicago    IL   Chicago       Cook         5
#
#    2010-10  2010-11  2010-12   ...     2017-03  2017-04  2017-05  2017-06  \
# 0    18.74    18.92    19.07   ...       24.91    24.60    25.48    26.20
# 1    13.27    13.20    13.20   ...       13.12    13.11    13.02    12.85
# 2    14.09    14.04    13.85   ...       14.33    14.17    14.00    13.97
# 3     8.83     9.04     8.99   ...        9.56     9.56     9.56     9.53
# 4    11.62    11.58    11.47   ...       10.49    10.37    10.36    10.41
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0    26.33    26.30    26.02    26.44    26.41    26.33
# 1    12.80    12.75    12.70    12.78    12.99    13.03
# 2    13.89    13.89    13.91    13.98    14.03    14.06
# 3     9.48     9.48     9.54     9.61     9.56     9.62
# 4    10.47    10.60    10.61    10.60    10.63    10.65
#
# [5 rows x 94 columns]

# %%
print(20)
print(list_of_file_names[20])
test_plot(read_data_list_2, range(7), 20, 7)
# Out:
# 20
# ./zillow_zipcode/Zip_PriceToRentRatio_AllHomes_rental_values.csv

# %%
read_data_list_2[19].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     84640       60640   Chicago    IL   Chicago       Cook         4
# 4     61807       10467  New York    NY  New York      Bronx         5
#
#    1997-02  1997-03  1997-04   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN    67.52   ...       57.46    52.19    59.65    62.92
# 1    72.85    73.39    73.92   ...       74.89    70.36    66.66    68.35
# 2    81.77    80.52    73.04   ...       67.50    60.74    58.31    59.14
# 3    56.07    59.23    60.83   ...       77.44    72.41    70.01    69.83
# 4    44.76    23.17    23.69   ...       89.87    87.24    89.49    90.66
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0    60.82    59.75    56.70    61.04    60.58    54.91
# 1    59.66    62.12    61.48    57.96    50.73    41.64
# 2    54.24    55.96    54.24    49.24    40.22    34.92
# 3    59.59    62.51    60.78    56.54    51.05    43.79
# 4    89.30    88.23    87.55    90.37    89.09    90.65
#
# [5 rows x 258 columns]

# %%
print(19)
print(list_of_file_names[19])
test_plot(read_data_list_2, range(4), 19, 7)
# Out:
# 19
# ./zillow_zipcode/Zip_PctOfHomesIncreasingInValues_AllHomes_home_values.csv

# %%
read_data_list_2[18].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     61639       10025  New York    NY  New York   New York         1
# 1     84654       60657   Chicago    IL   Chicago       Cook         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     84640       60640   Chicago    IL   Chicago       Cook         4
# 4     61807       10467  New York    NY  New York      Bronx         5
#
#    1997-02  1997-03  1997-04   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN    30.29   ...       33.94    39.95    32.82    31.85
# 1    21.91    22.86    22.61   ...       16.48    20.26    23.32    22.09
# 2    15.09    16.55    22.58   ...       23.68    29.26    31.18    31.05
# 3    39.83    35.52    34.23   ...       15.90    19.59    21.42    21.24
# 4    50.42    66.35    69.92   ...        7.11     7.50     5.54     4.77
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0    34.11    34.85    37.54    33.29    33.52    39.01
# 1    30.05    27.24    28.19    31.65    38.06    47.04
# 2    35.94    34.41    35.77    39.96    49.46    54.82
# 3    31.93    28.57    30.75    34.50    39.57    45.58
# 4     5.35     7.30     7.39     5.06     5.16     5.06
#
# [5 rows x 258 columns]

# %%
print(18)
print(list_of_file_names[18])
test_plot(read_data_list_2, range(4), 18, 7)
# Out:
# 18
# ./zillow_zipcode/Zip_PctOfHomesDecreasingInValues_AllHomes_home_values.csv

# %%
read_data_list_2[17].head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0     84654       60657   Chicago    IL   Chicago       Cook         1
# 1     61637       10023  New York    NY  New York   New York         2
# 2     84616       60614   Chicago    IL   Chicago       Cook         3
# 3     93144       79936   El Paso    TX   El Paso    El Paso         4
# 4     84640       60640   Chicago    IL   Chicago       Cook         5
#
#    1996-04  1996-05  1996-06   ...     2017-03  2017-04  2017-05  2017-06  \
# 0    134.0    134.0    133.0   ...         294      293      294      294
# 1      NaN      NaN      NaN   ...        1569     1573     1577     1567
# 2    149.0    150.0    150.0   ...         331      330      330      329
# 3     50.0     51.0     50.0   ...          81       81       81       82
# 4    110.0    109.0    107.0   ...         223      223      222      221
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0      293      293      294      294      294      293
# 1     1550     1535     1532     1538     1539     1539
# 2      327      326      327      327      325      325
# 3       82       82       83       83       83       83
# 4      220      220      221      222      222      222
#
# [5 rows x 268 columns]

# %%
print(17)
print(list_of_file_names[17])
test_plot(read_data_list_2, range(7), 17, 7)
# Out:
# 17
# ./zillow_zipcode/Zip_MedianValuePerSqft_AllHomes_home_values.csv

# %%
read_data_list_2[16].head()
# Out:
#    RegionName      City State     Metro CountyName  SizeRank  2010-03  \
# 0       10025  New York    NY  New York   New York         1      NaN
# 1       60657   Chicago    IL   Chicago       Cook         2      NaN
# 2       10023  New York    NY  New York   New York         3      NaN
# 3       60614   Chicago    IL   Chicago       Cook         4      NaN
# 4       79936   El Paso    TX   El Paso    El Paso         5      NaN
#
#    2010-04  2010-05  2010-06   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...      2600.0   2600.0   2567.0   2508.5
# 1      NaN      NaN      NaN   ...      1150.0   1100.0   1131.5   1125.0
# 2      NaN      NaN      NaN   ...      2800.0   2800.0   2800.0   2755.0
# 3      NaN      NaN      NaN   ...      1350.0   1325.0   1255.0   1250.0
# 4      NaN      NaN      NaN   ...      1000.0    995.0    995.0    995.0
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   2505.0   2510.0   2500.0   2500.0   2410.5   2577.0
# 1   1125.0   1095.0   1095.0   1094.0   1085.0   1075.0
# 2   2800.0   2755.0   2750.0   2765.0   2787.5   2765.0
# 3   1300.0   1350.0   1350.0   1400.0   1432.5   1405.0
# 4    995.0    995.0    975.0    995.0    985.0    995.0
#
# [5 rows x 100 columns]

# %%
print(16)
print(list_of_file_names[16])
test_plot(read_data_list_2, range(7), 16, 6)
# Out:
# 16
# ./zillow_zipcode/Zip_MedianRentalPrice_Studio_rental_listings.csv

# %%
read_data_list_2[15].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       10023     New York    NY           New York   New York         3
# 3       77494  Cinco Ranch    TX            Houston  Fort Bend         4
# 4       75070     McKinney    TX  Dallas-Fort Worth     Collin         5
#
#    2010-02  2010-03  2010-04  2010-05   ...     2017-03  2017-04  2017-05  \
# 0      NaN      NaN      NaN      NaN   ...      3297.5   3295.0   3350.0
# 1      NaN      NaN      NaN      NaN   ...      1950.0   2087.5   2200.0
# 2      NaN      NaN      NaN      NaN   ...      3095.0   3089.5   3080.0
# 3      NaN      NaN      NaN      NaN   ...      2000.0   2037.5   2000.0
# 4      NaN      NaN      NaN      NaN   ...      1895.0   1850.0   1850.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3295.0   3297.5   3400.0   3350.0   3300.0   3400.0   3402.5
# 1   2150.0   2300.0   2172.5   1947.5   1816.0   2050.0   2050.0
# 2   3043.0   3150.0   3150.0   3150.0   3043.0   3175.0   3217.0
# 3   2075.0   2100.0   2100.0   2200.0   2325.0   2250.0   2200.0
# 4   1895.0   1850.0   1875.0   1890.0   1850.0   1850.0   1850.0
#
# [5 rows x 101 columns]

# %%
print(15)
print(list_of_file_names[15])
test_plot(read_data_list_2, range(7), 15, 6)
# Out:
# 15
# ./zillow_zipcode/Zip_MedianRentalPrice_Sfr_rental_listings.csv

# %%
read_data_list_2[14].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       10023     New York    NY           New York   New York         3
# 3       77494  Cinco Ranch    TX            Houston  Fort Bend         4
# 4       75070     McKinney    TX  Dallas-Fort Worth     Collin         5
#
#    2010-02  2010-03  2010-04  2010-05   ...     2017-03  2017-04  2017-05  \
# 0      NaN      NaN   2640.0   2350.0   ...      3295.0   3295.0   3295.0
# 1      NaN   1347.5   1200.0   1272.5   ...      1650.0   1675.0   1710.0
# 2      NaN      NaN      NaN      NaN   ...      3455.0   3495.0   3500.0
# 3      NaN      NaN      NaN      NaN   ...      1332.0   1265.0   1329.0
# 4      NaN      NaN      NaN      NaN   ...      1214.5   1270.0   1229.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3250.0   3300.0   3375.0   3395.0   3357.5   3295.0   3295.0
# 1   1725.0   1695.0   1690.0   1650.0   1595.0   1550.0   1550.0
# 2   3500.0   3535.0   3500.0   3500.0   3590.0   3532.0   3500.0
# 3   1335.0   1335.0   1327.5   1390.0   1390.0   1430.0   1418.0
# 4   1250.0   1265.0   1265.0   1400.0   1391.5   1280.0   1258.0
#
# [5 rows x 101 columns]

# %%
print(14)
print(list_of_file_names[14])
test_plot(read_data_list_2, range(7), 14, 6)
# Out:
# 14
# ./zillow_zipcode/Zip_MedianRentalPrice_Mfr5Plus_rental_listings.csv

# %%
read_data_list_2[13].head()
# Out:
#    RegionName      City State     Metro CountyName  SizeRank  2010-10  \
# 0       10025  New York    NY  New York   New York         1      NaN
# 1       60657   Chicago    IL   Chicago       Cook         2      NaN
# 2       10023  New York    NY  New York   New York         3      NaN
# 3       60614   Chicago    IL   Chicago       Cook         4      NaN
# 4       10002  New York    NY  New York   New York         5      NaN
#
#    2010-11  2010-12  2011-01   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN   2675.0   ...      3100.0   3112.0   3100.0   3070.0
# 1      NaN      NaN      NaN   ...      1550.0   1545.0   1600.0   1650.0
# 2      NaN      NaN      NaN   ...      3200.0   3200.0   3235.5   3297.0
# 3      NaN      NaN      NaN   ...      1750.0   1750.0   1800.0   1875.0
# 4      NaN      NaN      NaN   ...      3062.5   3075.0   3200.0   3200.0
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3200.0   3250.0   3295.0   3200.0   3100.0   3115.0
# 1   1595.0   1595.0   1595.0   1575.0   1510.0   1505.0
# 2   3400.0   3300.0   3300.0   3400.0   3362.5   3303.0
# 3   1940.0   1880.0   1892.5   1850.0   1850.0   1885.0
# 4   3200.0   3196.5   3100.0   2995.0   2947.0   2895.0
#
# [5 rows x 93 columns]

# %%
print(13)
print(list_of_file_names[13])
test_plot(read_data_list_2, range(7), 13, 6)
# Out:
# 13
# ./zillow_zipcode/Zip_MedianRentalPrice_DuplexTriplex_rental_listings.csv

# %%
read_data_list_2[12].head()
# Out:
#    RegionName      City State     Metro CountyName  SizeRank  2010-02  \
# 0       10025  New York    NY  New York   New York         1      NaN
# 1       60657   Chicago    IL   Chicago       Cook         2      NaN
# 2       10023  New York    NY  New York   New York         3      NaN
# 3       60614   Chicago    IL   Chicago       Cook         4      NaN
# 4       60640   Chicago    IL   Chicago       Cook         5      NaN
#
#    2010-03  2010-04  2010-05   ...     2017-03  2017-04  2017-05  2017-06  \
# 0      NaN      NaN      NaN   ...      3450.0   3500.0   3500.0   3500.0
# 1      NaN      NaN      NaN   ...      1925.0   2000.0   2100.0   2100.0
# 2      NaN      NaN      NaN   ...      3850.0   3860.0   3950.0   3997.5
# 3      NaN      NaN      NaN   ...      2150.0   2178.5   2200.0   2192.5
# 4      NaN      NaN      NaN   ...      1650.0   1550.0   1550.0   1550.0
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3500.0   3500.0   3495.0   3400.0   3500.0   3500.0
# 1   2100.0   1995.0   1850.0   1825.0   1795.0   1750.0
# 2   3995.0   3835.0   3790.0   3800.0   3820.0   3820.0
# 3   2300.0   2300.0   2200.0   2050.0   2100.0   2100.0
# 4   1500.0   1500.0   1500.0   1450.0   1495.0   1462.5
#
# [5 rows x 101 columns]

# %%
print(12)
print(list_of_file_names[12])
test_plot(read_data_list_2, range(7), 12, 6)
# Out:
# 12
# ./zillow_zipcode/Zip_MedianRentalPrice_CondoCoop_rental_listings.csv

# %%
read_data_list_2[11].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       10023     New York    NY           New York   New York         3
# 3       77494  Cinco Ranch    TX            Houston  Fort Bend         4
# 4       75070     McKinney    TX  Dallas-Fort Worth     Collin         5
#
#    2010-02  2010-03  2010-04  2010-05   ...     2017-03  2017-04  2017-05  \
# 0      NaN      NaN      NaN      NaN   ...      3400.0   3500.0   3445.0
# 1      NaN      NaN      NaN      NaN   ...      1937.5   2000.0   2100.0
# 2      NaN      NaN      NaN      NaN   ...      3698.5   3725.0   3762.5
# 3      NaN      NaN      NaN      NaN   ...      2000.0   2000.0   2000.0
# 4      NaN      NaN      NaN      NaN   ...      1875.0   1850.0   1850.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3440.0   3405.0   3470.0   3405.0   3400.0   3495.0   3500.0
# 1   2100.0   2150.0   2000.0   1850.0   1816.0   1800.0   1795.0
# 2   3750.0   3800.0   3700.0   3600.0   3587.5   3700.0   3700.0
# 3   2000.0   2100.0   2100.0   2200.0   2260.0   2200.0   2200.0
# 4   1890.0   1850.0   1850.0   1860.0   1850.0   1850.0   1850.0
#
# [5 rows x 101 columns]

# %%
print(11)
print(list_of_file_names[11])
test_plot(read_data_list_2, range(7), 11, 6)
# Out:
# 11
# ./zillow_zipcode/Zip_MedianRentalPrice_AllHomes_rental_listings.csv

# %%
read_data_list_2[10].head()
# Out:
#    RegionName          City State                  Metro    CountyName  \
# 0       77494   Cinco Ranch    TX                Houston     Fort Bend
# 1        2135        Boston    MA                 Boston       Suffolk
# 2       92880      Eastvale    CA              Riverside     Riverside
# 3       33178         Doral    FL  Miami-Fort Lauderdale    Miami-Dade
# 4       19121  Philadelphia    PA           Philadelphia  Philadelphia
#
#    SizeRank  2011-12  2012-01  2012-02  2012-03   ...     2017-03  2017-04  \
# 0         1      NaN      NaN      NaN      NaN   ...      3000.0     3000
# 1         2      NaN   3200.0   3200.0   3200.0   ...      4350.0     4295
# 2         3      NaN      NaN   2500.0   2497.5   ...      2800.0     2765
# 3         4      NaN      NaN      NaN      NaN   ...      4275.0     4000
# 4         5      NaN      NaN      NaN      NaN   ...      3000.0     3000
#
#    2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0     3000   3000.0     3000     3000   3000.0     3300     3300   3300.0
# 1     4300   4300.0     4300     4300   4300.0     4200     4200   4300.0
# 2     2785   2800.0     2800     2800   2797.5     2790     2750   2797.5
# 3     3800   3900.0     4100     4500   4100.0     4500     4500   4500.0
# 4     3000   3000.0     2900     3000   3000.0     3150     3025   3000.0
#
# [5 rows x 79 columns]

# %%
print(10)
print(list_of_file_names[10])
test_plot(read_data_list_2, range(7), 10, 6)
# Out:
# 10
# ./zillow_zipcode/Zip_MedianRentalPrice_5BedroomOrMore_rental_listings.csv

# %%
read_data_list_2[9].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       77494  Cinco Ranch    TX            Houston  Fort Bend         3
# 3       75070     McKinney    TX  Dallas-Fort Worth     Collin         4
# 4       60614      Chicago    IL            Chicago       Cook         5
#
#    2011-01  2011-02  2011-03  2011-04   ...     2017-03  2017-04  2017-05  \
# 0      NaN      NaN      NaN      NaN   ...      5000.0   5000.0   5000.0
# 1      NaN      NaN      NaN      NaN   ...      3300.0   3585.0   3600.0
# 2      NaN      NaN      NaN      NaN   ...      2100.0   2200.0   2200.0
# 3      NaN      NaN   1597.5   1662.5   ...      1995.0   1995.0   1995.0
# 4      NaN      NaN      NaN      NaN   ...      3600.0   3800.0   4000.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   5000.0   4950.0   5000.0   4947.5   5000.0   4950.0   4847.5
# 1   3800.0   3600.0   3400.0   3372.5   3150.0   3000.0   3090.0
# 2   2200.0   2200.0   2250.0   2300.0   2400.0   2400.0   2400.0
# 3   1966.0   1900.0   1995.0   1990.0   1900.0   1900.0   1900.0
# 4   4150.0   3850.0   3650.0   3625.0   3550.0   3300.0   3300.0
#
# [5 rows x 90 columns]

# %%
print(9)
print(list_of_file_names[9])
test_plot(read_data_list_2, range(7), 9, 6)
# Out:
# 9
# ./zillow_zipcode/Zip_MedianRentalPrice_4Bedroom_rental_listings.csv

# %%
read_data_list_2[8].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       77494  Cinco Ranch    TX            Houston  Fort Bend         3
# 3       75070     McKinney    TX  Dallas-Fort Worth     Collin         4
# 4       60614      Chicago    IL            Chicago       Cook         5
#
#    2010-03  2010-04  2010-05  2010-06   ...     2017-03  2017-04  2017-05  \
# 0      NaN      NaN      NaN      NaN   ...      4440.0   4385.0   4300.0
# 1      NaN      NaN      NaN      NaN   ...      2695.0   2600.0   2695.0
# 2      NaN      NaN      NaN      NaN   ...      1750.0   1759.0   1769.0
# 3      NaN      NaN      NaN      NaN   ...      1750.0   1767.5   1795.0
# 4      NaN      NaN      NaN      NaN   ...      2900.0   2900.0   2950.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   4250.0   4297.5   4449.0   4497.0   4400.0   4500.0   4447.5
# 1   2700.0   2695.0   2700.0   2600.0   2519.0   2475.0   2495.0
# 2   1800.0   1802.5   1800.0   1800.0   1890.0   1850.0   1850.0
# 3   1795.0   1785.0   1750.0   1750.0   1775.0   1750.0   1750.0
# 4   2995.0   2850.0   2850.0   2800.0   2700.0   2700.0   2700.0
#
# [5 rows x 100 columns]

# %%
print(8)
print(list_of_file_names[8])
test_plot(read_data_list_2, range(7), 8, 6)
# Out:
# 8
# ./zillow_zipcode/Zip_MedianRentalPrice_3Bedroom_rental_listings.csv

# %%
read_data_list_2[7].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       10023     New York    NY           New York   New York         3
# 3       77494  Cinco Ranch    TX            Houston  Fort Bend         4
# 4       75070     McKinney    TX  Dallas-Fort Worth     Collin         5
#
#    2010-09  2010-10  2010-11  2010-12   ...     2017-03  2017-04  2017-05  \
# 0      NaN      NaN      NaN      NaN   ...      3500.0   3500.0   3495.0
# 1      NaN      NaN      NaN      NaN   ...      1975.0   1900.0   1935.0
# 2      NaN      NaN      NaN      NaN   ...      4900.0   4900.0   4990.0
# 3      NaN      NaN      NaN      NaN   ...      1528.0   1459.5   1526.5
# 4      NaN      NaN      NaN      NaN   ...      1434.5   1465.0   1475.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   3400.0   3399.0   3395.0   3500.0   3500.0   3695.0   3500.0
# 1   1945.0   1925.0   1920.0   1895.0   1850.0   1850.0   1800.0
# 2   4950.0   4900.0   4850.0   5000.0   5087.5   5000.0   4950.0
# 3   1600.0   1604.5   1590.0   1627.5   1610.0   1639.5   1635.0
# 4   1370.0   1392.0   1451.0   1511.5   1493.0   1439.0   1377.5
#
# [5 rows x 94 columns]

# %%
print(7)
print(list_of_file_names[7])
test_plot(read_data_list_2, range(7), 7, 6)
# Out:
# 7
# ./zillow_zipcode/Zip_MedianRentalPrice_2Bedroom_rental_listings.csv

# %%
read_data_list_2[6].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       10023     New York    NY           New York   New York         3
# 3       77494  Cinco Ranch    TX            Houston  Fort Bend         4
# 4       75070     McKinney    TX  Dallas-Fort Worth     Collin         5
#
#    2010-09  2010-10  2010-11  2010-12   ...     2017-03  2017-04  2017-05  \
# 0      NaN   2537.5   2555.0   2636.5   ...      3032.5   2995.0   2975.0
# 1      NaN      NaN      NaN      NaN   ...      1450.0   1450.0   1450.0
# 2      NaN   2995.0   3025.0   3000.0   ...      3255.0   3300.0   3300.0
# 3      NaN      NaN      NaN      NaN   ...      1130.0   1097.5   1119.0
# 4      NaN      NaN      NaN      NaN   ...       995.0   1026.0   1025.0
#
#    2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# 0   2900.0   2900.0   3000.0   3025.0   3000.0   2928.5   3014.0
# 1   1465.0   1450.0   1425.0   1400.0   1375.0   1360.0   1385.0
# 2   3300.0   3300.0   3297.5   3280.5   3295.0   3300.0   3300.0
# 3   1175.0   1165.0   1124.0   1190.0   1202.5   1179.0   1179.0
# 4   1020.0   1025.0   1030.0   1056.0   1055.0   1082.5   1070.0
#
# [5 rows x 94 columns]

# %%
print(6)
print(list_of_file_names[6])
test_plot(read_data_list_2, range(7), 6, 5)
# Out:
# 6
# ./zillow_zipcode/Zip_MedianRentalPrice_1Bedroom_rental_listings.csv

# %%
read_data_list_2[5].head()
# Out:
#    RegionID  RegionName      City    County State     Metro  SizeRank  \
# 0     61639       10025  New York  New York    NY  New York         1
# 1     84654       60657   Chicago      Cook    IL   Chicago         2
# 2     61637       10023  New York  New York    NY  New York         3
# 3     84616       60614   Chicago      Cook    IL   Chicago         4
# 4     93144       79936   El Paso   El Paso    TX   El Paso         5
#
#     2010-09   2010-10   2010-11    ...      2017-03   2017-04   2017-05  \
# 0  4.002965  3.629537  3.478425    ...     3.267974  3.853565  3.596038
# 1  3.797539  3.584229  3.511855    ...     2.886914  2.839230  3.121520
# 2  5.181347  5.453473  4.185263    ...     4.083333  3.921569  3.829734
# 3  3.790087  3.423968  3.626281    ...     3.125000  3.069368  3.003003
# 4  3.410888  3.740610  4.000000    ...     3.178990  3.576814  2.595938
#
#     2017-06   2017-07   2017-08   2017-09   2017-10   2017-11   2017-12
# 0  3.927409  4.000000  5.788386  4.892885  4.283333  4.468918  5.615079
# 1  2.600780  2.957531  2.421011  2.778086  2.783578  2.222222  2.186330
# 2  3.703704  4.048805  4.074074  3.870968  5.238095  4.327660  2.777778
# 3  3.204272  2.780482  2.847249  2.665205  2.632965  2.618858  2.174874
# 4  2.872237  2.831863  3.340659  3.303707  3.678181  2.838164  2.916667
#
# [5 rows x 95 columns]

# %%
print(5)
print(list_of_file_names[5])
test_plot(read_data_list_2, range(3), 5, 7)
# Out:
# 5
# ./zillow_zipcode/Zip_MedianPctOfPriceReduction_AllHomes_home_listings_and_sales.csv

# %%
read_data_list_2[4].head()
# Out:
#    RegionName         City State              Metro CountyName  SizeRank  \
# 0       10025     New York    NY           New York   New York         1
# 1       60657      Chicago    IL            Chicago       Cook         2
# 2       10023     New York    NY           New York   New York         3
# 3       77494  Cinco Ranch    TX            Houston  Fort Bend         4
# 4       75070     McKinney    TX  Dallas-Fort Worth     Collin         5
#
#     2010-01   2010-02   2010-03   2010-04    ...        2017-03    2017-04  \
# 0  775000.0  725000.0  762500.0  725000.0    ...      1450000.0  1497500.0
# 1  349900.0  349000.0  339169.5  346900.0    ...       510000.0   499900.0
# 2       NaN       NaN       NaN       NaN    ...      2505000.0  2462500.0
# 3  285000.0  285000.0  289900.0  289055.0    ...       373997.5   379000.0
# 4  191315.0  194900.0  190995.0  195000.0    ...       367990.0   374400.0
#
#      2017-05    2017-06    2017-07    2017-08    2017-09    2017-10  \
# 0  1467000.0  1400000.0  1332500.0  1325000.0  1295000.0  1397500.0
# 1   499000.0   500000.0   485000.0   485000.0   514000.0   500000.0
# 2  2397500.0  2425000.0  2500000.0  2405000.0  2395000.0  2390000.0
# 3   380000.0   379900.0   375000.0   375000.0   374950.0   374900.0
# 4   371995.0   368022.0   351593.5   350000.0   361092.0   369900.0
#
#      2017-11    2017-12
# 0  1485000.0  1537500.0
# 1   500000.0   529900.0
# 2  2450000.0  2495000.0
# 3   369900.0   366909.0
# 4   365000.0   368950.0
#
# [5 rows x 102 columns]

# %%
print(4)
print(list_of_file_names[4])
test_plot(read_data_list_2, range(7), 4, 6)
# Out:
# 4
# ./zillow_zipcode/Zip_MedianListingPrice_AllHomes_home_listings_and_sales.csv

# %%
read_data_list_2[3].head()
# Out:
#    RegionID  RegionName      City   County State              Metro  SizeRank  \
# 0     84654       60657   Chicago     Cook    IL            Chicago         2
# 1     84616       60614   Chicago     Cook    IL            Chicago         4
# 2     93144       79936   El Paso  El Paso    TX            El Paso         5
# 3     91733       77084   Houston   Harris    TX            Houston         8
# 4     90668       75070  McKinney   Collin    TX  Dallas-Fort Worth        10
#
#      2010-09    2010-10    2010-11    ...        2017-03    2017-04  \
# 0  11.836482  12.926298  13.578425    ...      28.082852  25.781556
# 1  10.583686  10.228192  13.048990    ...      15.306596  17.650569
# 2  11.599742  12.463938  14.308883    ...      14.467526  14.684354
# 3  16.930820  15.608901  13.695486    ...      14.842011  11.065269
# 4  12.596835  12.138152  13.965941    ...      15.058663  14.824366
#
#      2017-05    2017-06    2017-07    2017-08    2017-09    2017-10  \
# 0  18.874661  22.733670  18.696631  15.476597  20.773716  18.502027
# 1  18.999600  17.801941  18.021480  16.017275  13.986502  16.544237
# 2  17.284644  12.474645  11.883365  13.618595  11.454726  11.229428
# 3  11.966028  13.664771  16.430730  14.911292   9.577039  10.753842
# 4  15.468754  19.957663  22.819038  23.481998  23.337636  23.953098
#
#      2017-11    2017-12
# 0  16.348988  12.644990
# 1  13.550195  11.976519
# 2  14.746457  14.688100
# 3  13.101429  12.974148
# 4  21.504069  17.884343
#
# [5 rows x 95 columns]

# %%
print(3)
print(list_of_file_names[3])
test_plot(read_data_list_2, range(3), 3, 7)
# Out:
# 3
# ./zillow_zipcode/Zip_Listings_PriceCut_SeasAdj_SingleFamilyResidence_home_listings_and_sales.csv

# %%
read_data_list_2[2].head()
# Out:
#    RegionID  RegionName      City    County State     Metro  SizeRank  \
# 0     61639       10025  New York  New York    NY  New York         1
# 1     84654       60657   Chicago      Cook    IL   Chicago         2
# 2     61637       10023  New York  New York    NY  New York         3
# 3     84616       60614   Chicago      Cook    IL   Chicago         4
# 4     84640       60640   Chicago      Cook    IL   Chicago         6
#
#      2010-09    2010-10    2010-11    ...        2017-03    2017-04  \
# 0   7.392590  13.074145  12.695547    ...       8.807328   8.263237
# 1  16.340299  13.081332  14.026773    ...      12.375672  11.485071
# 2  12.186720  11.638770   7.655341    ...      10.182349   6.764525
# 3  17.792587  12.668053  14.826102    ...      17.059765  12.823876
# 4  18.180274  20.764426  16.193795    ...      14.159167  10.902248
#
#      2017-05    2017-06    2017-07    2017-08    2017-09    2017-10  \
# 0   6.648931   6.491591   8.335646   6.492719   8.875274   9.642772
# 1  15.159539  14.839257  17.647782  20.177685  18.024643  15.304427
# 2  10.091701   8.837330   7.816984   7.855542   8.100517  11.446507
# 3  16.553104  17.885887  17.329921  17.223605  15.213034  15.553613
# 4  10.502337  11.814394  13.341936  18.346213  14.198792  17.244003
#
#      2017-11    2017-12
# 0   9.286666   8.277206
# 1  14.667661  14.726743
# 2  11.079352   8.860353
# 3  14.176803  11.024541
# 4  17.194427  12.693815
#
# [5 rows x 95 columns]

# %%
print(2)
print(list_of_file_names[2])
test_plot(read_data_list_2, range(5), 2, 7)
# Out:
# 2
# ./zillow_zipcode/MarketHealthIndex_Zip_home_listings_and_sales.csv

# %%
read_data_list_2[1].head()
# Out:
#    RegionName RegionType         City CountyName              Metro  \
# 0       10025        Zip     New York   New York           New York
# 1       60657        Zip      Chicago       Cook            Chicago
# 2       10023        Zip     New York   New York           New York
# 3       77494        Zip  Cinco Ranch  Fort Bend            Houston
# 4       75070        Zip     McKinney     Collin  Dallas-Fort Worth
#
#   StateFullName DataTypeDescription  2010-01  2010-02  2010-03   ...     \
# 0      New York           All Homes      176      179      199   ...
# 1      Illinois           All Homes      666      726      825   ...
# 2      New York           All Homes      224      236      263   ...
# 3         Texas           All Homes      822      842      952   ...
# 4         Texas           All Homes      902      935     1056   ...
#
#    2017-03  2017-04  2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  \
# 0      140      142      149      144      142      132      142      188
# 1      320      338      348      373      391      389      412      408
# 2      294      338      366      375      348      314      352      377
# 3      678      783      839      894      932      828      736      696
# 4      282      310      367      414      496      643      608      616
#
#    2017-11  2017-12
# 0      177      139
# 1      344      278
# 2      374      335
# 3      689      632
# 4      601      491
#
# [5 rows x 103 columns]

# %%
print(1)
print(list_of_file_names[1])
test_plot(read_data_list_2, range(7), 1, 7)
# Out:
# 1
# ./zillow_zipcode/InventoryMeasure_Zip_Public_home_listings_and_sales.csv

# %%
read_data_list_2[0].head()
# Out:
#   RegionType  RegionName State   CBSA Title  SizeRankCity  SizeRankMetro  \
# 0        Zip       44240    OH  "Akron, OH"          3102             73
# 1        Zip       44203    OH  "Akron, OH"          3210             73
# 2        Zip       44224    OH  "Akron, OH"          3295             73
# 3        Zip       44266    OH  "Akron, OH"          4372             73
# 4        Zip       44221    OH  "Akron, OH"          4390             73
#
#    PctPriceCut  DaysOnMarket  BuyerSellerIndex  BuyerSellerIndexMetro
# 0    10.638298          62.5          2.500000               5.132128
# 1    11.864407          67.0          5.714286               5.132128
# 2    11.224490          55.0          1.785714               5.132128
# 3    12.751678          74.0         10.000000               5.132128
# 4     9.774436          65.0          3.214286               5.132128
